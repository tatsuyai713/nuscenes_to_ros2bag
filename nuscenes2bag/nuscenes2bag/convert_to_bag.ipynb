# %%
# !source /opt/ros/humble/setup.bash
# !cd /work
# !source install/local_setup.bash
# Out:
# /bin/bash: line 1: install/local_setup.bash: No such file or directory

# %%
from nuscenes.can_bus.can_bus_api import NuScenesCanBus
from nuscenes.eval.common.utils import quaternion_yaw
from nuscenes.map_expansion.map_api import NuScenesMap
from nuscenes.nuscenes import NuScenes

# %%
nusc = NuScenes(version="v1.0-mini", dataroot="/work/data", verbose=True)
nusc_can = NuScenesCanBus(dataroot="/work/data")
# Out:
# ======
# Loading NuScenes tables for version v1.0-mini...
# 23 category,
# 8 attribute,
# 4 visibility,
# 911 instance,
# 12 sensor,
# 120 calibrated_sensor,
# 31206 ego_pose,
# 8 log,
# 10 scene,
# 404 sample,
# 31206 sample_data,
# 18538 sample_annotation,
# 4 map,
# Done loading in 0.669 seconds.
# ======
# Reverse indexing ...
# Done reverse indexing in 0.2 seconds.
# ======

# %%
cur_sample = nusc.get("sample", nusc.scene[0]["first_sample_token"])

# %%
cur_sample["data"].items()
# Out:
# dict_items([('RADAR_FRONT', '37091c75b9704e0daa829ba56dfa0906'), ('RADAR_FRONT_LEFT', '11946c1461d14016a322916157da3c7d'), ('RADAR_FRONT_RIGHT', '491209956ee3435a9ec173dad3aaf58b'), ('RADAR_BACK_LEFT', '312aa38d0e3e4f01b3124c523e6f9776'), ('RADAR_BACK_RIGHT', '07b30d5eb6104e79be58eadf94382bc1'), ('LIDAR_TOP', '9d9bf11fb0e144c8b446d54a8a00184f'), ('CAM_FRONT', 'e3d495d4ac534d54b321f50006683844'), ('CAM_FRONT_RIGHT', 'aac7867ebf4f446395d29fbd60b63b3b'), ('CAM_BACK_RIGHT', '79dbb4460a6b40f49f9c150cb118247e'), ('CAM_BACK', '03bea5763f0f4722933508d5999c5fd8'), ('CAM_BACK_LEFT', '43893a033f9c46d4a51b5e08a67a1eb7'), ('CAM_FRONT_LEFT', 'fe5422747a7d4268a4b07fc396707b23')])

# %%
sample_data = nusc.get("sample_data", '9d9bf11fb0e144c8b446d54a8a00184f')

# %%
sample_data["filename"]
# Out:
# 'samples/LIDAR_TOP/n015-2018-07-24-11-22-45+0800__LIDAR_TOP__1532402927647951.pcd.bin'

# %%
from pathlib import Path

file = Path("/work/data") / sample_data["filename"]
with open(file, "rb") as f:
    print(f.read())
# Out:
# b'\xbc\xf5G\xc0dI\xde\xbe&\x00\xef\xbf\x00\x00\x80@\x00\x00\x00\x00\xc9\x99R\xc05J\xdd\xbe\xfc|\xee\xbf\x00\x00\x80?\x00\x00\x80?3\x1b^\xc08\x83\xdc\xbe\'\x06\xee\xbf\x00\x00\x00@\x00\x00\x00@\x10\xc2j\xc0DP\xdb\xbe\xf2\x90\xed\xbf\x00\x00@@\x00\x00@@\xab\x93y\xc0C\xee\xd9\xbe<\x1b\xee\xbf\x00\x00\xc0@\x00\x00\x80@\x03`\x85\xc0\xb9\xb6\xd8\xbe\xb6^\xef\xbf\x00\x00\xa0@\x00\x00\xa0@m\xa0\x8d\xc0\xd0\x1b\xd7\xbe\xf4w\xee\xbf\x00\x00\xe0@\x00\x00\xc0@\xca&\x98\xc0\xaf$\xd5\xbeX\x7f\xef\xbf\x00\x00\xb0A\x00\x00\xe0@\x80 \xa1\xc0\xa6\xb6\xd3\xbe\xa9m\xec\xbf\x00\x00@A\x00\x00\x00A\xcbJ\xa1\xc0\x91\xe1\xd2\xbel\xd9\xdb\xbf\x00\x00\xc0@\x00\x00\x10A\xf4\xf7\xac\xc0\x9e\x86\xd0\xbeE\xbe\xd9\xbf\x00\x004B\x00\x00 AEG\xbb\xc0 :\xce\xbeV\xa8\xd8\xbf\x00\x00\xe8A\x00\x000A!w\xca\xc0n)\xcb\xbe\x92\xdd\xd5\xbf\x00\x00\xf0A\x00\x00@A,\xc8\xda\xc0\x83g\xc8\xbeq6\xd1\xbf\x00\x00\x0cB\x00\x00PAG\xa3\xeb\xc0*\xd4\xc4\xbey4\xca\xbf\x00\x00$B\x00\x00`A\xc7J\x03\xc1\xf9\x8d\xbf\xbe\x83\xc1\xc7\xbf\x00\x000B\x00\x00pA\x0e\xd5\xaf\xc0\x84\x92\xd8\xbe\xb3\xd1j\xbf\x00\x00\xf8A\x00\x00\x80A4-(\xc1\xabS\xca\xbe\x90\xf4\xbe\xbf\x00\x00\xb0A\x00\x00\x88A\x9b\xf87\xc10\xbe\xc5\xbeb\xb9\xad\xbf\x00\x00\xa0@\x00\x00\x90A,\xf8Y\xc1IQ\xbd\xbe\xe0\x8f\xa4\xbf\x00\x00\xa0@\x00\x00\x98A\x98U\x84\xc1g\x1b\xb3\xbe\xa0\xf1\x95\xbf\x00\x00\x00@\x00\x00\xa0A(\xfc\xaf\xc19K\x9e\xbe\x904\x85\xbf\x00\x00\x10A\x00\x00\xa8At\xdb\xad\xc1y\xa7\x9b\xbe\x13\xf4\x04\xbf\x00\x00\xd0A\x00\x00\xb0AC\xb6\xad\xc1] \x9a\xbe\xb3Ir\xbc\x00\x00,B\x00\x00\xb8A<\x06\x07\xbaPW\xe7\xbe:Sm\xbc\x00\x00@@\x00\x00\xc0A\xa8\x7fc\xc1\x9d(\xb0\xbeg\xfd%?\x00\x00\xc0@\x00\x00\xc8A<\x06\x07\xbaPW\xe7\xbe:Sm\xbc\x00\x00\xe4B\x00\x00\xd0A\x84\x89b\xc1\x85\x0b\xad\xbe\xa33\xa7?\x00\x00\xb0B\x00\x00\xd8A\xe1\xa5b\xc16\xb8\xaa\xbe_)\xd2?\x00\x00\xaaB\x00\x00\xe0A\xd4Ib\xc1\xa4\xc8\xa9\xbe\xec\x8b\xfc?\x00\x00\xa2B\x00\x00\xe8A\x147b\xc1)\x84\xa7\xbe\xdc\xb9\x13@\x00\x00\x96B\x00\x00\xf0A\xb4\xf9a\xc1\xfcK\xa5\xbe\x18^)@\x00\x00 B\x00\x00\xf8A\x87fG\xc0\xcd\xe9\xd4\xbe\xc9W\xee\xbf\x00\x00\x80@\x00\x00\x00\x00\xcaAR\xc0\x1fj\xd3\xbeo\x1b\xee\xbf\x00\x00\x80?\x00\x00\x80?65^\xc0C\r\xd2\xbe\x9c#\xee\xbf\x00\x00\x00@\x00\x00\x00@\xc5\x16k\xc0\xba?\xd0\xbe\xd0\xe7\xed\xbf\x00\x00@@\x00\x00@@\xac\xcby\xc0m3\xce\xbe\xe9Q\xee\xbf\x00\x00\xc0@\x00\x00\x80@\\@\x85\xc0\x06>\xcc\xbe\xef\'\xef\xbf\x00\x00\xa0@\x00\x00\xa0@\xa0\xbc\x8d\xc0\x05\xd2\xc9\xbe\xef\xa8\xee\xbf\x00\x00\x00A\x00\x00\xc0@\x8a$\x98\xc0\xfd\xe8\xc6\xbe\xb9}\xef\xbf\x00\x00\xa8A\x00\x00\xe0@\xe0<\xa1\xc0\xcc\xa0\xc4\xbe\xce\x98\xec\xbf\x00\x00pA\x00\x00\x00A\xdeW\xa1\xc0\xe7\xcb\xc3\xbe\xb7\xec\xdb\xbf\x00\x00\xc0@\x00\x00\x10A\x01Y\xac\xc0_\x86\xc0\xbeJ\xf9\xd8\xbf\x00\x004B\x00\x00 A\xf4\x9a\xb9\xc0\xbf \xbd\xbe\xb4\xbe\xd6\xbf\x00\x00\xd0A\x00\x000A<\xb3\xca\xc0\x19>\xb8\xbe\xf6\x1d\xd6\xbf\x00\x00\xf0A\x00\x00@A\xeec\xdb\xc0M\xe4\xb3\xbek\xcb\xd1\xbf\x00\x00 B\x00\x00PA\x06_\xeb\xc0\x1a\xf6\xae\xbe\xb5\xfb\xc9\xbf\x00\x004B\x00\x00`A\xb6\xd7\x02\xc1\xf1[\xa7\xbe)\x15\xc7\xbf\x00\x00(B\x00\x00pA\xbf\x13\xb0\xc0\xaf\x1e\xc8\xbe\x1d#k\xbf\x00\x00\x98A\x00\x00\x80A\xce\n(\xc1\xf4,\xab\xbe\x0e\xcd\xbe\xbf\x00\x00\xb0A\x00\x00\x88A\xd4\xdd7\xc1v\xa7\xa3\xbeK\x9f\xad\xbf\x00\x00\xa0@\x00\x00\x90A\x16\xb4Y\xc1^\x08\x95\xbe][\xa4\xbf\x00\x00\xa0@\x00\x00\x98A\xe7&\x84\xc1\x9fA\x82\xbe\xd0\xba\x95\xbf\x00\x00\x00@\x00\x00\xa0AF\x0c\x06\xba\xff\x1f\xe7\xbe\x0b\x1am\xbc\x00\x00@@\x00\x00\xa8Az\xc4\xad\xc1\xf8\xd86\xbe>\xd9\x04\xbf\x00\x00\xc0@\x00\x00\xb0AF\x0c\x06\xba\xff\x1f\xe7\xbe\x0b\x1am\xbc\x00\x00\x90A\x00\x00\xb8A\x93\x1ed\xc1\x0b\x11\x88\xbe\x17\t\xa2>\x00\x00@@\x00\x00\xc0AF\x0c\x06\xba\xff\x1f\xe7\xbe\x0b\x1am\xbc\x00\x00\x84B\x00\x00\xc8AF\x0c\x06\xba\xff\x1f\xe7\xbe\x0b\x1am\xbc\x00\x00\xf0B\x00\x00\xd0A\x8bub\xc19\x1e\x83\xbeb+\xa7?\x00\x00\xb0B\x00\x00\xd8A\x84\x81b\xc1\xe7\xcb\x80\xbe\xdc\x0e\xd2?\x00\x00\xc2B\x00\x00\xe0A\xdd=b\xc1\xd0\xc5\x7f\xbe\xb9\x86\xfc?\x00\x00\xa0B\x00\x00\xe8A\xcf\x1ab\xc1?O{\xbe\xe2\xab\x13@\x00\x00\x9cB\x00\x ...
